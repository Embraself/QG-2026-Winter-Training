# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# markdown
# jupyter笔记1

# %% [markdown]
# 你好，世界

# %% [markdown]
# 个人简介
# 姓名：罗振坚
# 性别：男
# 年龄：19
# 学院：计算机学院
# 专业：计算机类
# 兴趣爱好：篮球，电影，旅游，摄影记录，社交交友
# 希望能够进入QG工作室，结识更多志同道合的同行人
